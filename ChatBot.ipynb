# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tkinter import *

# %%
root = Tk()
root.title("Chatbot")
def send():
    send = "You -> "+e.get()
    txt.insert(END, "n"+send)
    user = e.get().lower()
    if(user == "hello"):
        txt.insert(END, "n" + "Bot -> Hi")
    elif(user == "hi" or user == "hii" or user == "hiiii"):
        txt.insert(END, "n" + "Bot -> Hello")
    elif(e.get() == "how are you"):
        txt.insert(END, "n" + "Bot -> fine! and you")
    elif(user == "fine" or user == "i am good" or user == "i am doing good"):
        txt.insert(END, "n" + "Bot -> Great! how can I help you.")
    else:
        txt.insert(END, "n" + "Bot -> Sorry! I dind't got you")
    e.delete(0, END)
txt = Text(root)
txt.grid(row=0, column=0, columnspan=2)
e = Entry(root, width=100)
e.grid(row=1, column=0)
send = Button(root, text="Send", command=send).grid(row=1, column=1)
root.mainloop()

# %%
import nltk

# %%
from nltk.chat.util import Chat, reflections

# %%
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there",]
    ], 
    [
        r"what is your name ?",
        ["I am a bot created by Telebot. you can call me crazy!",]
    ],
    [
        r"how are you ?",
        ["I'm doing goodnHow about You ?",]
    ],
    [
        r"sorry (.*)",
        ["Its alright","Its OK, never mind",]
    ],
    [
        r"I am fine",
        ["Great to hear that, How can I help you?",]
    ],
    [
        r"i'm (.*) doing good",
        ["Nice to hear that","How can I help you?:)",]
    ],
    [
        r"(.*) age?",
        ["I'm a computer program dudenSeriously you are asking me this?",]
    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]
    ],
    [
        r"(.*) created ?",
        ["Raghav created me using Python's NLTK library ","top secret ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['Indore, Madhya Pradesh',]
    ],
    [
        r"how is weather in (.*)?",
        ["Weather in %1 is awesome like always","Too hot man here in %1","Too cold man here in %1","Never even heard about %1"]
    ],
    [
        r"i work in (.*)?",
        ["%1 is an Amazing company, I have heard about it. But they are in huge loss these days.",]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how (.*) health(.*)",
        ["I'm a computer program, so I'm always healthy ",]
    ],
    [
        r"(.*) (sports|game) ?",
        ["I'm a very big fan of Football",]
    ],
    [
        r"who (.*) sportsperson ?",
        ["Messy","Ronaldo","Roony"]
    ],
    [
        r"who (.*) (moviestar|actor)?",
        ["Brad Pitt"]
    ],
    [
        r"i am looking for online guides and courses to learn data science, can you suggest?",
        ["Crazy_Tech has many great articles with each step explanation along with code, you can explore"]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
]

# %%
def chat():
    print("Hi! I am a chatbot created by Telebot for your service")
    chat = Chat(pairs, reflections)
    chat.converse()
#initiate the conversation
if __name__ == "__main__":
    chat()
# Out:
# Hi! I am a chatbot created by Telebot for your service
# > hi
# Hey there
# > how are you
# I'm doing goodnHow about You ?
# > i am fine
# Great to hear that, How can I help you?
# > need information about data science
# None
# > which is your favourite sports
# I'm a very big fan of Football
# > and which sportsperson you love
# I'm a very big fan of Football
# > who is your favourite sportsperson
# I'm a very big fan of Football
# > who is your favourite sportsperson ?
# I'm a very big fan of Football
# > quit
# It was nice talking to you. See you soon :)

# %%
root = Tk()
root.title("Chatbot")
def send():
    send = "You -> "+e.get()
    txt.insert(END, "n"+send)
    user = e.get().lower()
    if(user == "hi"):
        txt.insert(END, "n" + "Bot -> Hello")
    elif(user == "hi" or user == "hii" or user == "hiiiiiii"):
        txt.insert(END, "n" + "Bot -> Hello")
    elif(e.get() == "how are you"):
        txt.insert(END, "n" + "Bot -> fine! and you")
    elif(user == "fine" or user == "i am good" or user == "i am doing good"):
        txt.insert(END, "n" + "Bot -> Great! how can I help you.")
    elif(user == "can  you tell me the score of virat kohli in ipl 2024." or user == "how many run score by virat kohli in ipl 2024"):
        txt.insert(END, "n" + "Bot -> score of virat kohli in ipl 2024 is 741.")
    elif(user == "who is the champions of ipl 2024" ):
        txt.insert(END, "n" + "Bot -> the champions of IPL 2024 is KKR.")
    else:
        txt.insert(END, "n" + "Bot -> Sorry! I dind't got you")
    e.delete(0, END)
txt = Text(root)
txt.grid(row=0, column=0, columnspan=2)
e = Entry(root, width=100)
e.grid(row=1, column=0)
send = Button(root, text="Send", command=send).grid(row=1, column=1)
root.mainloop()

# %%
# bot.py

from chatterbot import ChatBot

chatbot = ChatBot("Chatpot")

exit_conditions = (":q", "quit", "exit")
while True:
    query = input("> ")
    if query in exit_conditions:
        break
    else:
        print(f" {chatbot.get_response(query)}")

# %%
pip install chatterbot
# Out:
# ...
#   Obtaining dependency information for chatterbot from https://files.pythonhosted.org/packages/6c/0e/dac0d82f34f86bf509cf5ef3e2dfc5aa7d444bd843a2330ceb7d854f84f2/ChatterBot-1.0.5-py2.py3-none-any.whl.metadata
#   Using cached ChatterBot-1.0.5-py2.py3-none-any.whl.metadata (8.1 kB)
# ...
#   Obtaining dependency information for mathparse<0.2,>=0.1 from https://files.pythonhosted.org/packages/c3/e5/4910fb85950cb960fcf3f5aabe1c8e55f5c9201788a1c1302b570a7e1f84/mathparse-0.1.2-py3-none-any.whl.metadata
#   Using cached mathparse-0.1.2-py3-none-any.whl.metadata (776 bytes)
# ...
#   Obtaining dependency information for pint>=0.8.1 from https://files.pythonhosted.org/packages/76/1a/096c91c2006648fe28564e5884d59978962afe98de74b1c01bb5913d033f/Pint-0.23-py3-none-any.whl.metadata
#   Using cached Pint-0.23-py3-none-any.whl.metadata (8.1 kB)
# ...

# %%
import  subprocess

# %%
# !pip install chatterbot
# Out:
# ...
#   Obtaining dependency information for chatterbot from https://files.pythonhosted.org/packages/6c/0e/dac0d82f34f86bf509cf5ef3e2dfc5aa7d444bd843a2330ceb7d854f84f2/ChatterBot-1.0.5-py2.py3-none-any.whl.metadata
#   Using cached ChatterBot-1.0.5-py2.py3-none-any.whl.metadata (8.1 kB)
# ...
#   Obtaining dependency information for mathparse<0.2,>=0.1 from https://files.pythonhosted.org/packages/c3/e5/4910fb85950cb960fcf3f5aabe1c8e55f5c9201788a1c1302b570a7e1f84/mathparse-0.1.2-py3-none-any.whl.metadata
#   Using cached mathparse-0.1.2-py3-none-any.whl.metadata (776 bytes)
# ...
#   Obtaining dependency information for pint>=0.8.1 from https://files.pythonhosted.org/packages/76/1a/096c91c2006648fe28564e5884d59978962afe98de74b1c01bb5913d033f/Pint-0.23-py3-none-any.whl.metadata
#   Using cached Pint-0.23-py3-none-any.whl.metadata (8.1 kB)
# ...

# %%
pip install telebot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-telegram-bot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install telegram.ext.updater
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement telegram.ext.updater (from versions: none)
# ERROR: No matching distribution found for telegram.ext.updater

# %%
pip install telegram
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-telegram-bot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-telegram-bot==13.14
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from telegram.ext.updater import Updater 
from telegram.update import Update 
from telegram.ext.callbackcontext import CallbackContext 
from telegram.ext.commandhandler import CommandHandler 
from telegram.ext.messagehandler import MessageHandler 
from telegram.ext.filters import Filters
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from telegram.ext.updater import Updater
#       2 from telegram.update import Update
#       3 from telegram.ext.callbackcontext import CallbackContext
#
# File ~\anaconda3\Lib\site-packages\telegram\ext\updater.py:42
#      27 from time import sleep
#      28 from typing import (
#      29     TYPE_CHECKING,
#      30     Any,
#    (...)
#      39     overload,
#      40 )
# ---> 42 from telegram import Bot, TelegramError
#      43 from telegram.error import InvalidToken, RetryAfter, TimedOut, Unauthorized
#      44 from telegram.ext import Dispatcher, JobQueue, ContextTypes, ExtBot
#
# ImportError: cannot import name 'TelegramError' from 'telegram' (C:\Users\LENOVO\anaconda3\Lib\site-packages\telegram\__init__.py)
